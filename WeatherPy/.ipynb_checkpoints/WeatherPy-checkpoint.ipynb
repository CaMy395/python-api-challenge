# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
lngs
# Out:
# array([ -72.72054012,  126.84656425,  162.21091245, ...,  -94.3222027 ,
#        -105.22732952,   61.9566697 ])

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pangoa
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | kirakira
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | juneau
# Processing Record 6 of Set 1 | olonkinbyen
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | kosh-agach
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | rabo de peixe
# Processing Record 11 of Set 1 | buala
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | kerikeri
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | atafu village
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | coquimbo
# Processing Record 19 of Set 1 | muzayri'
# City not found. Skipping...
# Processing Record 20 of Set 1 | qarqaraly
# Processing Record 21 of Set 1 | tangalle
# Processing Record 22 of Set 1 | luumaki
# Processing Record 23 of Set 1 | taltal
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | puerto natales
# Processing Record 26 of Set 1 | grytviken
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | sanya
# Processing Record 29 of Set 1 | lerwick
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | korla
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | papatowai
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | blackmans bay
# Processing Record 36 of Set 1 | yanchep
# Processing Record 37 of Set 1 | santa elena de uairen
# Processing Record 38 of Set 1 | tazovsky
# Processing Record 39 of Set 1 | selfoss
# Processing Record 40 of Set 1 | whitehorse
# Processing Record 41 of Set 1 | remire-montjoly
# Processing Record 42 of Set 1 | palmer
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | polyarnyy
# Processing Record 45 of Set 1 | traverse city
# Processing Record 46 of Set 1 | al jawf
# Processing Record 47 of Set 1 | urzhar
# Processing Record 48 of Set 1 | bowen
# Processing Record 49 of Set 1 | las khorey
# Processing Record 50 of Set 1 | male
# Processing Record 0 of Set 2 | tura
# Processing Record 1 of Set 2 | bilibino
# Processing Record 2 of Set 2 | stanley
# Processing Record 3 of Set 2 | holualoa
# Processing Record 4 of Set 2 | neiafu
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | hawaiian paradise park
# Processing Record 7 of Set 2 | kununurra
# Processing Record 8 of Set 2 | anadyr
# Processing Record 9 of Set 2 | college
# Processing Record 10 of Set 2 | adamstown
# Processing Record 11 of Set 2 | priozersk
# Processing Record 12 of Set 2 | gereida
# Processing Record 13 of Set 2 | pathein
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | edinburgh of the seven seas
# Processing Record 16 of Set 2 | charters towers
# Processing Record 17 of Set 2 | acapulco de juarez
# Processing Record 18 of Set 2 | kapa'a
# Processing Record 19 of Set 2 | wailua homesteads
# Processing Record 20 of Set 2 | isle of lewis
# City not found. Skipping...
# Processing Record 21 of Set 2 | beerwah
# Processing Record 22 of Set 2 | beboto
# Processing Record 23 of Set 2 | sokhumi
# Processing Record 24 of Set 2 | haapsalu
# Processing Record 25 of Set 2 | brookings
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | laojunmiao
# Processing Record 29 of Set 2 | marble falls
# Processing Record 30 of Set 2 | aasiaat
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | vorkuta
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | chenaran
# Processing Record 35 of Set 2 | isla mujeres
# Processing Record 36 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 37 of Set 2 | el reno
# Processing Record 38 of Set 2 | invercargill
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | suzun
# Processing Record 41 of Set 2 | shush
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | argo
# Processing Record 44 of Set 2 | wahpeton
# Processing Record 45 of Set 2 | hoemul-li
# Processing Record 46 of Set 2 | nuku'alofa
# Processing Record 47 of Set 2 | richards bay
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | ballina
# Processing Record 39 of Set 4 | akureyri
# Processing Record 40 of Set 4 | ha'il
# Processing Record 41 of Set 4 | christchurch
# Processing Record 42 of Set 4 | naze
# Processing Record 43 of Set 4 | vila franca do campo
# Processing Record 44 of Set 4 | urangan
# Processing Record 45 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 46 of Set 4 | zagon
# Processing Record 47 of Set 4 | papao
# Processing Record 48 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 49 of Set 4 | maumere
# Processing Record 0 of Set 5 | gebeit
# Processing Record 1 of Set 5 | ornskoldsvik
# Processing Record 2 of Set 5 | sisimiut
# Processing Record 3 of Set 5 | puerto colombia
# Processing Record 4 of Set 5 | eyl
# Processing Record 5 of Set 5 | mezhdurechenskiy
# Processing Record 6 of Set 5 | dudinka
# Processing Record 7 of Set 5 | erenhot
# Processing Record 8 of Set 5 | san juan de miraflores
# Processing Record 9 of Set 5 | weno
# Processing Record 10 of Set 5 | yarmouth
# Processing Record 11 of Set 5 | kavalerovo
# Processing Record 12 of Set 5 | cascais
# Processing Record 13 of Set 5 | ostersund
# Processing Record 14 of Set 5 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 16 of Set 5 | sao felix do xingu
# Processing Record 17 of Set 5 | mar del plata
# Processing Record 18 of Set 5 | imbituba
# Processing Record 19 of Set 5 | saint-pierre
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | mariental
# Processing Record 22 of Set 5 | sirte
# Processing Record 23 of Set 5 | hadibu
# Processing Record 24 of Set 5 | karaton
# Processing Record 25 of Set 5 | totness
# Processing Record 26 of Set 5 | port elizabeth
# Processing Record 27 of Set 5 | nar'yan-mar
# Processing Record 28 of Set 5 | thanh hoa
# Processing Record 29 of Set 5 | taroa
# Processing Record 30 of Set 5 | alice springs
# Processing Record 31 of Set 5 | crane
# Processing Record 32 of Set 5 | smithers
# Processing Record 33 of Set 5 | la paz
# Processing Record 34 of Set 5 | sodankyla
# Processing Record 35 of Set 5 | vernon
# Processing Record 36 of Set 5 | gomez farias
# Processing Record 37 of Set 5 | kawambwa
# Processing Record 38 of Set 5 | san
# Processing Record 39 of Set 5 | vorgashor
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | port hedland
# Processing Record 42 of Set 5 | zinjibar
# Processing Record 43 of Set 5 | east london
# Processing Record 44 of Set 5 | saint-paul
# Processing Record 45 of Set 5 | zapolyarnyy
# Processing Record 46 of Set 5 | al mijlad
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | scottburgh
# Processing Record 49 of Set 5 | guerrero negro
# Processing Record 0 of Set 6 | george town
# Processing Record 1 of Set 6 | porto belo
# Processing Record 2 of Set 6 | andapa
# Processing Record 3 of Set 6 | badger
# Processing Record 4 of Set 6 | tamanrasset
# Processing Record 5 of Set 6 | tralee
# Processing Record 6 of Set 6 | haiku-pauwela
# Processing Record 7 of Set 6 | dolinsk
# Processing Record 8 of Set 6 | sechura
# Processing Record 9 of Set 6 | wildwood
# Processing Record 10 of Set 6 | saipan
# Processing Record 11 of Set 6 | alness
# Processing Record 12 of Set 6 | chhutmalpur
# Processing Record 13 of Set 6 | uturoa
# Processing Record 14 of Set 6 | huocheng
# City not found. Skipping...
# Processing Record 15 of Set 6 | loralai
# Processing Record 16 of Set 6 | camiri
# Processing Record 17 of Set 6 | tazacorte
# Processing Record 18 of Set 6 | kone
# Processing Record 19 of Set 6 | gao
# Processing Record 20 of Set 6 | petauke
# Processing Record 21 of Set 6 | alamogordo
# Processing Record 22 of Set 6 | inarajan village
# Processing Record 23 of Set 6 | pemangkat
# Processing Record 24 of Set 6 | libenge
# Processing Record 25 of Set 6 | newman
# Processing Record 26 of Set 6 | sandnessjoen
# Processing Record 27 of Set 6 | ajaccio
# Processing Record 28 of Set 6 | extrema
# Processing Record 29 of Set 6 | kuala terengganu
# Processing Record 30 of Set 6 | hoxtolgay
# City not found. Skipping...
# Processing Record 31 of Set 6 | kill devil hills
# Processing Record 32 of Set 6 | mount gambier
# Processing Record 33 of Set 6 | picos
# Processing Record 34 of Set 6 | ciudad serdan
# Processing Record 35 of Set 6 | touros
# Processing Record 36 of Set 6 | zouerate
# Processing Record 37 of Set 6 | nemuro
# Processing Record 38 of Set 6 | st. john's
# Processing Record 39 of Set 6 | yuanping
# Processing Record 40 of Set 6 | sinabang
# Processing Record 41 of Set 6 | jiangyou
# Processing Record 42 of Set 6 | mount darwin
# Processing Record 43 of Set 6 | norwell
# Processing Record 44 of Set 6 | paita
# Processing Record 45 of Set 6 | tete
# Processing Record 46 of Set 6 | timbuktu
# Processing Record 47 of Set 6 | quelimane
# Processing Record 48 of Set 6 | atibaia
# Processing Record 49 of Set 6 | trairi
# Processing Record 0 of Set 7 | tome acu
# Processing Record 1 of Set 7 | bowie
# Processing Record 2 of Set 7 | rio san juan
# Processing Record 3 of Set 7 | zakrzow
# Processing Record 4 of Set 7 | machico
# Processing Record 5 of Set 7 | utrik
# Processing Record 6 of Set 7 | galliano
# Processing Record 7 of Set 7 | lusambo
# Processing Record 8 of Set 7 | mesyagutovo
# Processing Record 9 of Set 7 | nizhniy odes
# Processing Record 10 of Set 7 | al kharj
# Processing Record 11 of Set 7 | drahichyn
# Processing Record 12 of Set 7 | fortaleza
# Processing Record 13 of Set 7 | klaksvik
# Processing Record 14 of Set 7 | mozarlandia
# Processing Record 15 of Set 7 | barcelos
# Processing Record 16 of Set 7 | mucumpiz
# Processing Record 17 of Set 7 | patnongon
# Processing Record 18 of Set 7 | aykhal
# Processing Record 19 of Set 7 | tanumah
# Processing Record 20 of Set 7 | vallenar
# Processing Record 21 of Set 7 | kruisfontein
# Processing Record 22 of Set 7 | lammi
# Processing Record 23 of Set 7 | mana
# Processing Record 24 of Set 7 | el abiodh sidi cheikh
# Processing Record 25 of Set 7 | chibougamau
# Processing Record 26 of Set 7 | saudarkrokur
# Processing Record 48 of Set 8 | ibarra
# Processing Record 49 of Set 8 | franklin
# Processing Record 0 of Set 9 | conduaga
# Processing Record 1 of Set 9 | victorica
# Processing Record 2 of Set 9 | tyukhtet
# Processing Record 3 of Set 9 | susuman
# Processing Record 4 of Set 9 | cairns city
# City not found. Skipping...
# Processing Record 5 of Set 9 | kirensk
# Processing Record 6 of Set 9 | letlhakeng
# Processing Record 7 of Set 9 | merizo village
# Processing Record 8 of Set 9 | khandyga
# Processing Record 9 of Set 9 | padang
# Processing Record 10 of Set 9 | val-d'or
# Processing Record 11 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 9 | balkanabat
# Processing Record 15 of Set 9 | prince rupert
# Processing Record 16 of Set 9 | miguel aleman (la doce)
# City not found. Skipping...
# Processing Record 17 of Set 9 | yuzhno-kurilsk
# Processing Record 18 of Set 9 | dhanera
# Processing Record 19 of Set 9 | meadow lakes
# Processing Record 20 of Set 9 | pulandian
# Processing Record 21 of Set 9 | woodstock
# Processing Record 22 of Set 9 | sanming
# Processing Record 23 of Set 9 | vilyuchinsk
# Processing Record 24 of Set 9 | umluj
# Processing Record 25 of Set 9 | broken hill
# Processing Record 26 of Set 9 | shimanovsk
# Processing Record 27 of Set 9 | mashava
# Processing Record 28 of Set 9 | carnarvon
# Processing Record 29 of Set 9 | antigonish
# Processing Record 30 of Set 9 | marsh harbour
# Processing Record 31 of Set 9 | booue
# Processing Record 32 of Set 9 | lauro de freitas
# Processing Record 33 of Set 9 | oriximina
# Processing Record 34 of Set 9 | havre
# Processing Record 35 of Set 9 | pandan
# Processing Record 36 of Set 9 | guiuan
# Processing Record 37 of Set 9 | dakhla
# Processing Record 38 of Set 9 | dera bugti
# Processing Record 39 of Set 9 | barpeta
# Processing Record 40 of Set 9 | beypore
# Processing Record 41 of Set 9 | bol'sherech'ye
# Processing Record 42 of Set 9 | kingston
# Processing Record 43 of Set 9 | aitape
# Processing Record 44 of Set 9 | behshahr
# Processing Record 45 of Set 9 | chernyshevskiy
# Processing Record 46 of Set 9 | ganye
# Processing Record 47 of Set 9 | tobruk
# Processing Record 48 of Set 9 | kharan
# Processing Record 49 of Set 9 | safford
# Processing Record 0 of Set 10 | iquitos
# Processing Record 1 of Set 10 | nizamabad
# Processing Record 2 of Set 10 | labrador city
# Processing Record 3 of Set 10 | progreso
# Processing Record 4 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | frederikshavn
# Processing Record 7 of Set 10 | itoman
# Processing Record 8 of Set 10 | nantucket
# Processing Record 9 of Set 10 | janiuay
# Processing Record 10 of Set 10 | puerto lempira
# Processing Record 11 of Set 10 | melekeok village
# Processing Record 12 of Set 10 | tchintabaraden
# Processing Record 13 of Set 10 | oak bay
# Processing Record 14 of Set 10 | tual
# Processing Record 15 of Set 10 | jinxiang
# Processing Record 16 of Set 10 | colonia
# Processing Record 17 of Set 10 | al burayqah
# Processing Record 18 of Set 10 | mata-utu
# Processing Record 19 of Set 10 | sao gabriel da cachoeira
# Processing Record 20 of Set 10 | alakurtti
# Processing Record 21 of Set 10 | redding
# Processing Record 22 of Set 10 | kudahuvadhoo
# Processing Record 23 of Set 10 | aracati
# Processing Record 24 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 10 | leava
# Processing Record 26 of Set 10 | majene
# Processing Record 27 of Set 10 | san patricio
# Processing Record 28 of Set 10 | nguigmi
# Processing Record 29 of Set 10 | miranda
# Processing Record 30 of Set 10 | longjiang
# Processing Record 31 of Set 10 | sao vicente
# Processing Record 32 of Set 10 | san felipe
# Processing Record 33 of Set 10 | puquio
# Processing Record 34 of Set 10 | umm ruwaba
# Processing Record 35 of Set 10 | wafangdian
# Processing Record 36 of Set 10 | roma
# Processing Record 37 of Set 10 | mangrol
# Processing Record 38 of Set 10 | nkove
# Processing Record 39 of Set 10 | jiquilisco
# Processing Record 40 of Set 10 | krasnoyarskaya
# Processing Record 41 of Set 10 | el segundo
# Processing Record 42 of Set 10 | praia da vitoria
# Processing Record 43 of Set 10 | tsirang
# Processing Record 44 of Set 10 | porangatu
# Processing Record 45 of Set 10 | tejen
# Processing Record 46 of Set 10 | joshimath
# Processing Record 47 of Set 10 | ayvacik
# Processing Record 48 of Set 10 | lagos
# Processing Record 49 of Set 10 | margate
# Processing Record 0 of Set 11 | altamira
# Processing Record 1 of Set 11 | alofi
# Processing Record 2 of Set 11 | homer
# Processing Record 3 of Set 11 | astrakhan
# Processing Record 4 of Set 11 | taoudenni
# Processing Record 5 of Set 11 | constantia
# Processing Record 6 of Set 11 | wakkanai
# Processing Record 7 of Set 11 | eraan
# Processing Record 8 of Set 11 | isyangulovo
# Processing Record 9 of Set 11 | parambu
# Processing Record 10 of Set 11 | enriquillo
# Processing Record 11 of Set 11 | howrah
# Processing Record 12 of Set 11 | ciudad melchor muzquiz
# Processing Record 13 of Set 11 | afaahiti
# Processing Record 14 of Set 11 | altos del rosario
# Processing Record 15 of Set 11 | revda
# Processing Record 16 of Set 11 | arar
# Processing Record 17 of Set 11 | yeppoon
# Processing Record 18 of Set 11 | dongola
# Processing Record 19 of Set 11 | north battleford
# Processing Record 20 of Set 11 | hami
# Processing Record 21 of Set 11 | muisne
# Processing Record 22 of Set 11 | la huacana
# Processing Record 23 of Set 11 | saint-philippe
# Processing Record 24 of Set 11 | cabo san lucas
# Processing Record 25 of Set 11 | shantipur
# Processing Record 26 of Set 11 | union city
# Processing Record 27 of Set 11 | shalqar
# Processing Record 28 of Set 11 | peace river
# Processing Record 29 of Set 11 | tshikapa
# Processing Record 30 of Set 11 | gangtok
# Processing Record 31 of Set 11 | las heras
# Processing Record 32 of Set 11 | howard springs
# Processing Record 33 of Set 11 | stony plain
# Processing Record 34 of Set 11 | nema
# Processing Record 35 of Set 11 | banda aceh
# Processing Record 36 of Set 11 | woodlake
# Processing Record 37 of Set 11 | tuy hoa
# Processing Record 38 of Set 11 | la ronge
# Processing Record 39 of Set 11 | inari
# Processing Record 40 of Set 11 | natal
# Processing Record 41 of Set 11 | oulu
# Processing Record 42 of Set 11 | yallahs
# Processing Record 43 of Set 11 | tevragh zeina
# City not found. Skipping...
# Processing Record 44 of Set 11 | negapatam
# Processing Record 45 of Set 11 | nanded
# City not found. Skipping...
# Processing Record 46 of Set 11 | safotu
# Processing Record 47 of Set 11 | riosucio
# Processing Record 48 of Set 11 | praia
# Processing Record 49 of Set 11 | maryville
# Processing Record 0 of Set 12 | capitan bermudez
# Processing Record 1 of Set 12 | keelung
# Processing Record 2 of Set 12 | salalah
# Processing Record 3 of Set 12 | novo-talitsy
# City not found. Skipping...
# Processing Record 4 of Set 12 | mount isa
# Processing Record 5 of Set 12 | kegen
# Processing Record 6 of Set 12 | porto velho
# Processing Record 7 of Set 12 | zaigrayevo
# Processing Record 8 of Set 12 | tatarka
# Processing Record 9 of Set 12 | tafalla
# Processing Record 10 of Set 12 | broome
# Processing Record 11 of Set 12 | verkhnevilyuysk
# Processing Record 12 of Set 12 | luderitz
# Processing Record 13 of Set 12 | posto da mata
# City not found. Skipping...
# Processing Record 14 of Set 12 | sabang
# Processing Record 15 of Set 12 | tateyama
# Processing Record 16 of Set 12 | konarka
# Processing Record 17 of Set 12 | tranqueras
# Processing Record 18 of Set 12 | paradera
# City not found. Skipping...
# Processing Record 19 of Set 12 | gaalkacyo
# Processing Record 20 of Set 12 | hammerfest
# Processing Record 21 of Set 12 | okondja
# Processing Record 22 of Set 12 | kamyshlov
# Processing Record 23 of Set 12 | hirara
# Processing Record 24 of Set 12 | vuosaari
# Processing Record 25 of Set 12 | kiunga
# Processing Record 26 of Set 12 | kuanda
# Processing Record 27 of Set 12 | sao joao da barra
# Processing Record 28 of Set 12 | tachilek
# City not found. Skipping...
# Processing Record 29 of Set 12 | nacala
# Processing Record 30 of Set 12 | beyneu
# Processing Record 31 of Set 12 | friedrichstadt
# Processing Record 32 of Set 12 | barra de santo antonio
# Processing Record 33 of Set 12 | kyshtovka
# Processing Record 34 of Set 12 | sanibel
# Processing Record 35 of Set 12 | mirnyy
# Processing Record 36 of Set 12 | beira
# Processing Record 37 of Set 12 | prado
# Processing Record 38 of Set 12 | karratha
# Processing Record 39 of Set 12 | maceio
# Processing Record 40 of Set 12 | maych'ew
# Processing Record 41 of Set 12 | serowe
# Processing Record 42 of Set 12 | turinsk
# Processing Record 43 of Set 12 | gisborne
# Processing Record 44 of Set 12 | necochea
# Processing Record 45 of Set 12 | ta'if
# Processing Record 46 of Set 12 | auki
# Processing Record 47 of Set 12 | kristiansund
# Processing Record 48 of Set 12 | okha
# Processing Record 49 of Set 12 | suva
# Processing Record 0 of Set 13 | laksar
# Processing Record 1 of Set 13 | lesogorsk
# Processing Record 2 of Set 13 | pergamino
# Processing Record 3 of Set 13 | basco
# Processing Record 4 of Set 13 | xifeng
# Processing Record 5 of Set 13 | dryden
# Processing Record 6 of Set 13 | mascouche
# Processing Record 7 of Set 13 | nevada
# Processing Record 8 of Set 13 | gillette
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
Record_count = city_data_df.count()
print(f"Record Count: {Record_count}")
# Out:
# Record Count: City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    pangoa -12.1167  -73.0000    293.69        99          65        0.83
# 1     tiksi  71.6872  128.8694    247.11        89          99        1.48
# 2  kirakira -10.4544  161.9205    301.99        79          49        5.21
# 3    hasaki  35.7333  140.8333    279.42        79         100        8.30
# 4    juneau  58.3019 -134.4197    274.15        97         100        3.09
#
#   Country        Date
# 0      PE  1707197490
# 1      RU  1707197491
# 2      SB  1707197492
# 3      JP  1707197492
# 4      US  1707197291

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../WeatherPy/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../WeatherPy/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          pangoa -12.1167  -73.0000    293.69        99          65
# 1           tiksi  71.6872  128.8694    247.11        89          99
# 2        kirakira -10.4544  161.9205    301.99        79          49
# 3          hasaki  35.7333  140.8333    279.42        79         100
# 4          juneau  58.3019 -134.4197    274.15        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.83      PE  1707197490
# 1              1.48      RU  1707197491
# 2              5.21      SB  1707197492
# 3              8.30      JP  1707197492
# 4              3.09      US  1707197291

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speeds")
plt.xlabel("Latitude")
plt.ylabel("Wind Speeds")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, eqn_coordinates):
    
    # Calculate correlation coefficient
    correlation_coefficient = st.pearsonr(x, y)[0]
    print(f"The r-value is: {correlation_coefficient}")

    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

    # Plot the regression line
    plt.plot(x, regress_values, "r-", label="Linear Regression")

    # Annotate the line equation on the plot
    plt.annotate(line_eq, eqn_coordinates, fontsize=12, color="red")

    # Scatter plot of the data
    plt.scatter(x, y, label="Data Points")

    # Adding Labels
    plt.xlabel(f"{x.name}")
    plt.ylabel(f"{y.name}")
    plt.legend()

    # Display the plot
    plt.show()
    
    
    return rvalue

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
North_Hem_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
North_Hem_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              tiksi  71.6872  128.8694    247.11        89          99
# 3             hasaki  35.7333  140.8333    279.42        79         100
# 4             juneau  58.3019 -134.4197    274.15        97         100
# 5        olonkinbyen  70.9221   -8.7187    271.35        72          60
# 7         kosh-agach  50.0000   88.6667    253.88        87          50
#
#          Wind Speed Country        Date
# City_ID
# 1              1.48      RU  1707197491
# 3              8.30      JP  1707197492
# 4              3.09      US  1707197291
# 5              4.26      SJ  1707197493
# 7              0.45      RU  1707197495

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
South_Hem_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
South_Hem_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   pangoa -12.1167  -73.0000    293.69        99          65
# 2                 kirakira -10.4544  161.9205    301.99        79          49
# 6        port-aux-francais -49.3500   70.2167    278.92        71         100
# 8                 waitangi -43.9535 -176.5597    293.05        85          98
# 10                   buala  -8.1450  159.5921    302.83        73          94
#
#          Wind Speed Country        Date
# City_ID
# 0              0.83      PE  1707197490
# 2              5.21      SB  1707197492
# 6             12.30      TF  1707197494
# 8              0.89      NZ  1707197496
# 10             4.43      SB  1707197497

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
North_Line_Reg = linear_regression_plot(North_Hem_df["Lat"].rename("Latitude"), North_Hem_df["Max Temp"], (0, 245))
# Out:
# The r-value is: -0.8938791041052473

# %%
# Linear regression on Southern Hemisphere
South_Line_Reg = linear_regression_plot(South_Hem_df["Lat"].rename("Latitude"), South_Hem_df["Max Temp"], (-25, 286))
# Out:
# The r-value is: 0.4289740406953977

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern hemisphere, the negative r-value indicates a negative correlation between the temperature and latitude. We can see that the temperature starts to decrease as it moves away from the origin (equator:lat = 0). This simply means that as one decreases the other increases. In the Southern hemisphere, the positive r-value indicates a positive correlation between the temperature and latitude. We can see that the temperature starts to increase as it moves toward from the origin (equator:lat = 0). This makes sense because the equatore is considered the the closest part to the sun. So, it can be concluded that when near the equator, the temperature is higher.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Southern Hemisphere
N_Line_Reg_Hum = linear_regression_plot(North_Hem_df["Lat"].rename("Latitude"), North_Hem_df["Humidity"], (50, 30))
# Out:
# The r-value is: 0.44753108094611044

# %%
# Southern Hemisphere
S_Line_Reg_Hum = linear_regression_plot(South_Hem_df["Lat"].rename("Latitude"), South_Hem_df["Humidity"], (-20, 30))
# Out:
# The r-value is: 0.31950782748050205

# %% [markdown]
# **Discussion about the linear relationship:** The linear regressions seen above for the North and South hemisphere both have positive r-values indicating a positive correlation between humidity and the latitude. However, the r-values are not very strong with the North having a higher correlation in comparison to the South. Also although they have positive r-values, humidity increases heading towards the equator in the South hemisphere, while the  humidity increases heading away from the equator in the North hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Southern Hemisphere
N_Line_Reg_Cloud = linear_regression_plot(North_Hem_df["Lat"].rename("Latitude"), North_Hem_df["Cloudiness"], (50, 19))
# Out:
# The r-value is: 0.2619115829328815

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
S_Line_Reg_Cloud = linear_regression_plot(South_Hem_df["Lat"].rename("Latitude"), South_Hem_df["Cloudiness"], (-55, 20))
# Out:
# The r-value is: 0.23934879276806498

# %% [markdown]
# **Discussion about the linear relationship:** The linear regressions seen above for the North and South hemisphere both have positive r-values indicating a positive correlation between cloudiness and the latitude. However, the r-values are not very strong with the South having a higher correlation in comparison to the North. Also although they have positive r-values, cloudiness increases heading towards the equator in the South hemisphere, while the  cloudiness increases heading away from the equator in the North hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
N_Line_Reg_Wind = linear_regression_plot(North_Hem_df["Lat"].rename("Latitude"), North_Hem_df["Wind Speed"], (0, 15))
# Out:
# The r-value is: -0.0869934387962498

# %%
# Southern Hemisphere
S_Line_Reg_Wind = linear_regression_plot(South_Hem_df["Lat"].rename("Latitude"), South_Hem_df["Wind Speed"], (-55, 13))
# Out:
# The r-value is: -0.1083173550688802

# %% [markdown]
# **Discussion about the linear relationship:** The linear regressions seen above for the North and South hemisphere both have positive and negative r-values respectively, indicating a positive correlation between Wind Speed and the latitude for the North (although minute) and negative correlation for the South. However, the r-values are not very strong with the South having a higher negative correlation in comparison to the North's positve correlation. Also although they have positive r-values, Wind Speed decreases heading towards the equator in the South hemisphere, while the Wind Speed increases heading away from the equator in the North hemisphere. The small r-value in the North hemisphere indicates the small slope. It can be concluded that when near the equator, Wind Speed is lower.
